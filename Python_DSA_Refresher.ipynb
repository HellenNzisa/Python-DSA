# %%
"""1. Write a program that asks the user for a number of days. The program then
prints out the number of seconds in the amount of days given. """

def days_to_seconds():
    # Ask for a number of days
    days = int(input("Enter the number of days: "))
    
    # Calculate the number of seconds in the given number of days
    seconds = days * 24 * 60 * 60
    print(f"There are {seconds} seconds in {days} days.")

days_to_seconds()
# Out:
# There are 172800 seconds in 2 days.

# %%
""""2. Write a program that asks a user to input the radius then the program
calculates the volume of a sphere (the formula for the volume is (4/3)πr3
).
Use the exponential operator in python to compute (r3
)"""

def sphere_volume():
    import math
    
    # Ask for radius
    radius = float(input("Enter the radius of the sphere: "))
    
    # Calculate the volume of the sphere
    volume = (4/3) * math.pi * (radius ** 3)

    print(f"The volume of the sphere with radius {radius} is {volume:.2f} cubic units.")

sphere_volume()
# Out:
# The volume of the sphere with radius 2.0 is 33.51 cubic units.

# %%
"""3. Using functions, write a program to compute the area and perimeter of a
square. The program should ask the user to enter a number corresponding to
the side length of the square and display the area and perimeter of the
square."""

def square_area_perimeter():
    #ask for length of the square
    side_length = float(input("Enter the side length of the square: "))
    
    # Calculate the area and perimeter of the square
    area = side_length * side_length
    perimeter = 4 * side_length
    
    print(f"The area of the square with side length {side_length} is {area}.")
    
    print(f"The perimeter of the square with side length {side_length} is {perimeter}.")

square_area_perimeter()
# Out:
# The area of the square with side length 4.0 is 16.0.
# The perimeter of the square with side length 4.0 is 16.0.

# %%
"""4. Write a program using functions that determines whether a character input
by a user is uppercase or lower case."""

def check_case():
    # Ask for input
    char = input("Enter a single character: ")
    
    # Check
    if len(char) != 1:
        print("Please enter only one character.")
        return
    
    # Determine if the character is uppercase or lowercase
    if char.isupper():
        print(f"The character '{char}' is uppercase.")
    elif char.islower():
        print(f"The character '{char}' is lowercase.")
    else:
        print(f"The character '{char}' is not an alphabetic letter.")


check_case()
# Out:
# The character 'h' is lowercase.

# %%
"""5.
The following is pseudocode for a program being designed. Write the Python program equivalent of the same.
Pseudocode: BEGIN
SET x TO 0, y TO 20
REPEAT
SUBTRACT 4 FROM y
ADD 2/y TO x
UNTIL
y IS LESS THAN 6
DISPLAY x
END """


x = 0
y = 20

while y > 6:
    y -= 4
    x += 2/y

print(x)
# Out:
# 1.0416666666666665

# %%
""".
Write a Python program that does the following:
•
Uses a loop for a user to continually input 5 values to populate an array.
•
Calculates and displays the average of the values input into the array."""

def average_of_values():
    values = []
    
    # Looping
    for i in range(5):
        value = float(input(f"Enter value {i + 1}: "))
        values.append(value)
    
    # Calculate the average
    average = sum(values) / len(values)
    
    print(f"The average of the entered values is: {average}")

average_of_values()
# Out:
# The average of the entered values is: 2.6

# %% [markdown]
# ## Codility Question
# A non-empty array A consisting of N numbers is given. The array is sorted in non-decreasing order. The absolute distinct count of this array is the number of distinct absolute values among the elements of the array.
#
# For example, consider array A such that:
#
#   A[0] = -5
#   A[1] = -3
#   A[2] = -1
#   A[3] =  0
#   A[4] =  3
#   A[5] =  6
#
# content_copy
# The absolute distinct count of this array is 5, because there are 5 distinct absolute values among the elements of this array, namely 0, 1, 3, 5 and 6.
#
# Write a function:
#
# def solution(A)
# content_copy
#
# that, given a non-empty array A consisting of N numbers, returns absolute distinct count of array A.
#
# For example, given array A such that:
#
#   A[0] = -5
#   A[1] = -3
#   A[2] = -1
#   A[3] =  0
#   A[4] =  3
#   A[5] =  6
#
# content_copy
# the function should return 5, as explained above.
#
# Write an efficient algorithm for the following assumptions:
#
# N is an integer within the range [1..100,000];
# each element of array A is an integer within the range [−2,147,483,648..2,147,483,647];
# array A is sorted in non-decreasing order.

# %%
"""Code for codility exercise"""

def solution(A):
    distinct_values = set()

    for number in A:
        distinct_values.add(abs(number))

    return len(distinct_values)
